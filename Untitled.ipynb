# %%
#Download Dataset

from roboflow import Roboflow

rf = Roboflow(api_key="ulcNVi2QOZNvT0xomzed")
project = rf.workspace("duckietown-3pgbf").project("duckiebots-traffic-image")
version = project.version(4)
dataset = version.download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Generating version still in progress. Progress: 100.0%

# %%
import os
import cv2
import matplotlib.pyplot as plt

root = os.getcwd()
img_path = root + '/datasets/segmentation/trainTRACKimg/24.jpg'

image = cv2.imread(img_path)
plt.imshow(image)

# %%
mask_path = root + '/datasets/segmentation/trainTRACKmask/24.png'
mask = cv2.imread(mask_path, 0)
print(mask.shape)


mask[mask!=0]=1
# mask[mask==4]=1
mask = 1-mask

plt.imshow(mask, cmap='gray')
# Out:
# (640, 640)

# %%
import numpy as np
a = np.array([[2,3],[1,2],[3,4],[4,5]])
plt.plot(a)
plt.
